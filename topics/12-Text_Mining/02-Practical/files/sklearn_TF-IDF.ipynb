# %% [markdown]
# # TF-IDF applied to Inaugural Addresses using Scikit-Learn

# %% [markdown]
# This notebook is based on [TF-IDF with Scikit-Learn](https://melaniewalsh.github.io/Intro-Cultural-Analytics/05-Text-Analysis/03-TF-IDF-Scikit-Learn.html)
#
# We are going to calculate tf-idf scores using the Python library scikit-learn, which has a module called [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# We will apply this to calculate tf-idf scores for U.S. Inaugural Addresses.

# %% [markdown]
# Import necessary modules and libraries

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %% [markdown]
# We are going to look for the "interesting" words in the inaugural speeches. In this case, we wish to see which president said what, so rather than using the NLTK corpus, we use [the same data from kaggle](https://www.kaggle.com/code/pabheeshta/us-presidential-inaugural-speeches).
#
# You should download this data and put it in a `data` folder below where you put this notebook.

# %%
speechDf = pd.read_csv('data/inaug_speeches.csv', usecols=['Name','Date','text'], encoding='latin1')
speechDf.head()
# Out:
#                 Name                      Date  \
# 0  George Washington  Thursday, April 30, 1789
# 1  George Washington     Monday, March 4, 1793
# 2         John Adams   Saturday, March 4, 1797
# 3   Thomas Jefferson  Wednesday, March 4, 1801
# 4   Thomas Jefferson     Monday, March 4, 1805
#
#                                                 text
# 0             Fellow-Citizens of the Senate and o...
# 1              Fellow Citizens:    I AM again cal...
# 2                WHEN it was first perceived, in ...
# 3              Friends and Fellow-Citizens:    CA...
# 4                PROCEEDING, fellow-citizens, to ...

# %% [markdown]
# We need to prepare the dataframe so that we can label each speech appropriately.

# %%
speechDf['year'] = pd.DatetimeIndex(speechDf['Date']).year
speechDf['year_Name'] = speechDf['year'].astype(str).str.cat(speechDf[['Name']], sep="_")
speechDf.head()
# Out:
#                 Name                      Date  \
# 0  George Washington  Thursday, April 30, 1789
# 1  George Washington     Monday, March 4, 1793
# 2         John Adams   Saturday, March 4, 1797
# 3   Thomas Jefferson  Wednesday, March 4, 1801
# 4   Thomas Jefferson     Monday, March 4, 1805
#
#                                                 text  year  \
# 0             Fellow-Citizens of the Senate and o...  1789
# 1              Fellow Citizens:    I AM again cal...  1793
# 2                WHEN it was first perceived, in ...  1797
# 3              Friends and Fellow-Citizens:    CA...  1801
# 4                PROCEEDING, fellow-citizens, to ...  1805
#
#                 year_Name
# 0  1789_George Washington
# 1  1793_George Washington
# 2         1797_John Adams
# 3   1801_Thomas Jefferson
# 4   1805_Thomas Jefferson

# %% [markdown]
# ## Calculate tf–idf

# %% [markdown]
# To calculate tf–idf scores for every word, we're going to use scikit-learn's [`TfidfVectorizer`](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).
#
# When you initialize TfidfVectorizer, you can choose to set it with different parameters. These parameters will change the way you calculate tf–idf.

# %% [markdown]
# The recommended way to run `TfidfVectorizer` is with smoothing (`smooth_idf = True`) and normalization (`norm='l2'`) turned on. These parameters will better account for differences in text length, and overall produce more meaningful tf–idf scores. Smoothing and L2 normalization are actually the default settings for `TfidfVectorizer`, so to turn them on, you don't need to include any extra code at all.

# %% [markdown]
# Initialize TfidfVectorizer with desired parameters (default smoothing and normalization)

# %%
tfidf_vectorizer = TfidfVectorizer(input='content', stop_words='english')

# %% [markdown]
# Run TfidfVectorizer on the `text` in `speechDf`.

# %%
tfidf_vector = tfidf_vectorizer.fit_transform(speechDf["text"])

# %% [markdown]
# Make a DataFrame out of the resulting tf–idf vector, setting the "feature names" or words as columns and the titles as rows

# %%
tfidf_df = pd.DataFrame(tfidf_vector.toarray(), index=speechDf['year_Name'], columns=tfidf_vectorizer.get_feature_names_out())

# %% [markdown]
# Add column for document frequency aka number of times word appears in all documents

# %%
tfidf_df.loc['00_Document Frequency'] = (tfidf_df > 0).sum()

# %%
tfidf_slice = tfidf_df[['government', 'borders', 'people', 'obama', 'war', 'honor','foreign', 'men', 'women', 'children']]
tfidf_slice.sort_index().round(decimals=2)
# Out:
#                              government  borders  people  obama    war  honor  \
# year_Name
# 00_Document Frequency             53.00     5.00   56.00   1.00  45.00  32.00
# 1789_George Washington             0.11     0.00    0.05   0.00   0.00   0.00
# 1793_George Washington             0.06     0.00    0.06   0.00   0.00   0.09
# 1797_John Adams                    0.16     0.00    0.19   0.00   0.01   0.10
# 1801_Thomas Jefferson              0.16     0.00    0.02   0.00   0.01   0.04
# 1805_Thomas Jefferson              0.03     0.00    0.00   0.00   0.04   0.00
# 1809_James Madison                 0.00     0.00    0.02   0.00   0.02   0.05
# 1813_James Madison                 0.04     0.00    0.04   0.00   0.26   0.02
# 1817_James Monroe                  0.17     0.00    0.11   0.00   0.09   0.01
# 1821_James Monroe                  0.08     0.00    0.07   0.00   0.11   0.02
# 1825_John Quincy Adams             0.15     0.00    0.06   0.00   0.05   0.01
# 1829_Andrew Jackson                0.10     0.00    0.06   0.00   0.02   0.02
# 1833_Andrew Jackson                0.21     0.00    0.14   0.00   0.00   0.00
# 1837_Martin Van Buren              0.11     0.00    0.14   0.00   0.02   0.02
# 1841_William Henry Harrison        0.14     0.00    0.14   0.00   0.01   0.02
# 1845_James Knox Polk               0.26     0.00    0.08   0.00   0.03   0.01
# 1849_Zachary Taylor                0.12     0.00    0.05   0.00   0.00   0.02
# 1853_Franklin Pierce               0.08     0.00    0.05   0.00   0.00   0.02
# 1857_James Buchanan                0.12     0.00    0.11   0.00   0.08   0.01
# 1861_Abraham Lincoln               0.12     0.00    0.13   0.00   0.02   0.00
# 1865_Abraham Lincoln               0.02     0.00    0.00   0.00   0.27   0.00
# 1869_Ulysses S. Grant              0.05     0.00    0.03   0.00   0.02   0.05
# 1873_Ulysses S. Grant              0.06     0.00    0.10   0.00   0.05   0.02
# 1877_Rutherford B. Hayes           0.17     0.00    0.08   0.00   0.00   0.00
# 1881_James A. Garfield             0.19     0.00    0.16   0.00   0.05   0.00
# 1885_Grover Cleveland              0.21     0.00    0.21   0.00   0.00   0.00
# 1889_Benjamin Harrison             0.06     0.00    0.17   0.00   0.02   0.03
# 1893_Grover Cleveland              0.15     0.00    0.22   0.00   0.00   0.00
# 1897_William McKinley              0.16     0.00    0.16   0.00   0.05   0.03
# 1901_William McKinley              0.16     0.00    0.12   0.00   0.08   0.05
# 1905_Theodore Roosevelt            0.05     0.00    0.10   0.00   0.00   0.00
# 1909_William Howard Taft           0.12     0.00    0.03   0.00   0.03   0.01
# 1913_Woodrow Wilson                0.11     0.00    0.02   0.00   0.00   0.00
# 1917_Woodrow Wilson                0.00     0.00    0.08   0.00   0.07   0.00
# 1921_Warren G. Harding             0.08     0.00    0.05   0.00   0.12   0.00
# 1925_Calvin Coolidge               0.10     0.00    0.10   0.00   0.02   0.01
# 1929_Herbert Hoover                0.22     0.04    0.11   0.00   0.02   0.00
# 1933_Franklin D. Roosevelt         0.03     0.00    0.08   0.00   0.02   0.02
# 1937_Franklin D. Roosevelt         0.18     0.03    0.12   0.00   0.01   0.00
# 1941_Franklin D. Roosevelt         0.05     0.00    0.09   0.00   0.00   0.00
# 1945_Franklin D. Roosevelt         0.00     0.00    0.02   0.00   0.05   0.03
# 1949_Harry S. Truman               0.03     0.00    0.10   0.00   0.02   0.01
# 1953_Dwight D. Eisenhower          0.01     0.00    0.10   0.00   0.04   0.03
# 1957_Dwight D. Eisenhower          0.00     0.00    0.11   0.00   0.01   0.05
# 1961_John F. Kennedy               0.00     0.00    0.01   0.00   0.06   0.00
# 1965_Lyndon Baines Johnson         0.01     0.00    0.11   0.00   0.01   0.00
# 1969_Richard Milhous Nixon         0.05     0.00    0.13   0.00   0.03   0.03
# 1973_Richard Milhous Nixon         0.10     0.00    0.06   0.00   0.03   0.01
# 1977_Jimmy Carter                  0.06     0.00    0.08   0.00   0.02   0.00
# 1981_Ronald Reagan                 0.15     0.00    0.08   0.00   0.01   0.00
# 1985_Ronald Reagan                 0.16     0.00    0.14   0.00   0.01   0.01
# 1989_George Bush                   0.05     0.00    0.06   0.00   0.03   0.00
# 1993_Bill Clinton                  0.05     0.00    0.13   0.00   0.03   0.00
# 1997_Bill Clinton                  0.08     0.00    0.09   0.00   0.01   0.00
# 2001_George W. Bush                0.05     0.00    0.01   0.00   0.01   0.00
# 2005_George W. Bush                0.03     0.05    0.05   0.00   0.00   0.04
# 2009_Barack Obama                  0.03     0.03    0.06   0.00   0.02   0.01
# 2013_Barack Obama                  0.04     0.00    0.10   0.00   0.03   0.00
# 2017_Donald J. Trump               0.03     0.10    0.11   0.13   0.00   0.00
#
#                              foreign    men  women  children
# year_Name
# 00_Document Frequency          32.00  47.00  15.00     22.00
# 1789_George Washington          0.00   0.02   0.00      0.00
# 1793_George Washington          0.00   0.00   0.00      0.00
# 1797_John Adams                 0.12   0.04   0.00      0.00
# 1801_Thomas Jefferson           0.00   0.04   0.00      0.00
# 1805_Thomas Jefferson           0.06   0.01   0.00      0.02
# 1809_James Madison              0.05   0.00   0.00      0.00
# 1813_James Madison              0.02   0.00   0.00      0.00
# 1817_James Monroe               0.10   0.04   0.00      0.00
# 1821_James Monroe               0.04   0.01   0.00      0.01
# 1825_John Quincy Adams          0.08   0.03   0.00      0.00
# 1829_Andrew Jackson             0.07   0.02   0.00      0.00
# 1833_Andrew Jackson             0.02   0.00   0.00      0.00
# 1837_Martin Van Buren           0.06   0.02   0.00      0.01
# 1841_William Henry Harrison     0.03   0.03   0.00      0.00
# 1845_James Knox Polk            0.09   0.02   0.00      0.01
# 1849_Zachary Taylor             0.05   0.00   0.00      0.00
# 1853_Franklin Pierce            0.04   0.01   0.00      0.03
# 1857_James Buchanan             0.04   0.03   0.00      0.05
# 1861_Abraham Lincoln            0.02   0.00   0.00      0.00
# 1865_Abraham Lincoln            0.00   0.04   0.00      0.00
# 1869_Ulysses S. Grant           0.05   0.02   0.00      0.00
# 1873_Ulysses S. Grant           0.00   0.00   0.00      0.00
# 1877_Rutherford B. Hayes        0.04   0.02   0.00      0.00
# 1881_James A. Garfield          0.00   0.01   0.00      0.04
# 1885_Grover Cleveland           0.05   0.01   0.00      0.00
# 1889_Benjamin Harrison          0.01   0.04   0.00      0.00
# 1893_Grover Cleveland           0.00   0.04   0.00      0.00
# 1897_William McKinley           0.06   0.02   0.00      0.00
# 1901_William McKinley           0.02   0.01   0.00      0.00
# 1905_Theodore Roosevelt         0.00   0.08   0.00      0.10
# 1909_William Howard Taft        0.03   0.03   0.00      0.00
# 1913_Woodrow Wilson             0.00   0.14   0.10      0.06
# 1917_Woodrow Wilson             0.00   0.05   0.00      0.00
# 1921_Warren G. Harding          0.00   0.01   0.00      0.00
# 1925_Calvin Coolidge            0.02   0.02   0.02      0.00
# 1929_Herbert Hoover             0.01   0.04   0.03      0.01
# 1933_Franklin D. Roosevelt      0.03   0.02   0.00      0.00
# 1937_Franklin D. Roosevelt      0.00   0.10   0.07      0.02
# 1941_Franklin D. Roosevelt      0.00   0.07   0.03      0.00
# 1945_Franklin D. Roosevelt      0.00   0.10   0.05      0.04
# 1949_Harry S. Truman            0.01   0.06   0.00      0.00
# 1953_Dwight D. Eisenhower       0.00   0.07   0.00      0.00
# 1957_Dwight D. Eisenhower       0.00   0.06   0.00      0.00
# 1961_John F. Kennedy            0.00   0.01   0.00      0.00
# 1965_Lyndon Baines Johnson      0.02   0.03   0.00      0.05
# 1969_Richard Milhous Nixon      0.00   0.01   0.00      0.00
# 1973_Richard Milhous Nixon      0.00   0.00   0.00      0.02
# 1977_Jimmy Carter               0.02   0.00   0.00      0.00
# 1981_Ronald Reagan              0.00   0.02   0.04      0.09
# 1985_Ronald Reagan              0.00   0.03   0.04      0.00
# 1989_George Bush                0.01   0.04   0.08      0.07
# 1993_Bill Clinton               0.02   0.01   0.02      0.06
# 1997_Bill Clinton               0.00   0.00   0.02      0.09
# 2001_George W. Bush             0.00   0.00   0.00      0.08
# 2005_George W. Bush             0.00   0.02   0.04      0.00
# 2009_Barack Obama               0.00   0.04   0.08      0.05
# 2013_Barack Obama               0.00   0.03   0.04      0.05
# 2017_Donald J. Trump            0.05   0.02   0.05      0.04

# %% [markdown]
# Let's drop "OO_Document Frequency" since we were just using it for illustration purposes.

# %%
tfidf_df = tfidf_df.drop('00_Document Frequency', errors='ignore')

# %% [markdown]
# Let's reorganize the DataFrame so that the words are in rows rather than columns.

# %%
tfidf_df.stack().reset_index()
# Out:
#                      year_Name    level_1         0
# 0       1789_George Washington       0085  0.000000
# 1       1789_George Washington       0092  0.000000
# 2       1789_George Washington       0093  0.000000
# 3       1789_George Washington       0094  0.000000
# 4       1789_George Washington       0097  0.014789
# ...                        ...        ...       ...
# 514107    2017_Donald J. Trump   youthful  0.000000
# 514108    2017_Donald J. Trump       zeal  0.000000
# 514109    2017_Donald J. Trump    zealous  0.000000
# 514110    2017_Donald J. Trump  zealously  0.000000
# 514111    2017_Donald J. Trump       zone  0.000000
#
# [514112 rows x 3 columns]

# %%
tfidf_df = tfidf_df.stack().reset_index()

# %%
tfidf_df = tfidf_df.rename(columns={0:'tfidf', 'level_0': 'year_Name','level_1': 'term', 'level_2': 'term'})

# %% [markdown]
# To find out the top 10 words with the highest tf–idf for every story, we're going to sort by document and tfidf score and then groupby year_Name and take the first 10 values.

# %%
tfidf_df.sort_values(by=['year_Name','tfidf'], ascending=[True,False]).groupby(['year_Name']).head(10)
# Out:
#                      year_Name          term     tfidf
# 3593    1789_George Washington    government  0.114344
# 3988    1789_George Washington     immutable  0.104489
# 4055    1789_George Washington   impressions  0.104489
# 6213    1789_George Washington  providential  0.104489
# 5512    1789_George Washington         ought  0.104333
# ...                        ...           ...       ...
# 509760    2017_Donald J. Trump          jobs  0.134850
# 511443    2017_Donald J. Trump     protected  0.125096
# 513178    2017_Donald J. Trump         thank  0.109974
# 510951    2017_Donald J. Trump        people  0.106140
# 506179    2017_Donald J. Trump       borders  0.101138
#
# [580 rows x 3 columns]

# %%
top_tfidf = tfidf_df.sort_values(by=['year_Name','tfidf'], ascending=[True,False]).groupby(['year_Name']).head(10)

# %% [markdown]
# We can zoom in on particular words and particular documents.

# %%
top_tfidf[top_tfidf['term'].str.contains('women')]
# Out:
# Empty DataFrame
# Columns: [year_Name, term, tfidf]
# Index: []

# %% [markdown]
# It turns out that the term "women" is very distinctive in Obama's Inaugural Address.

# %%
top_tfidf[top_tfidf['year_Name'].str.contains('Obama')]
# Out:
#                 year_Name        term     tfidf
# 487521  2009_Barack Obama        0092  0.317896
# 487524  2009_Barack Obama        0097  0.219136
# 487866  2009_Barack Obama     america  0.136347
# 492747  2009_Barack Obama      nation  0.110501
# 492808  2009_Barack Obama         new  0.108454
# 487520  2009_Barack Obama        0085  0.100977
# 491049  2009_Barack Obama  generation  0.092509
# 495537  2009_Barack Obama       today  0.090431
# 492215  2009_Barack Obama         let  0.083729
# 492032  2009_Barack Obama        jobs  0.083386
# 496385  2013_Barack Obama        0092  0.336508
# 496388  2013_Barack Obama        0097  0.221880
# 500904  2013_Barack Obama     journey  0.154751
# 498224  2013_Barack Obama       creed  0.128960
# 499913  2013_Barack Obama  generation  0.117511
# 496730  2013_Barack Obama     america  0.115464
# 497832  2013_Barack Obama    complete  0.106088
# 503056  2013_Barack Obama    requires  0.106088
# 502087  2013_Barack Obama      people  0.101897
# 504385  2013_Barack Obama        time  0.097475

# %%
top_tfidf[top_tfidf['year_Name'].str.contains('Trump')]
# Out:
#                    year_Name       term     tfidf
# 505594  2017_Donald J. Trump    america  0.330747
# 505249  2017_Donald J. Trump       0092  0.321310
# 507772  2017_Donald J. Trump     dreams  0.153805
# 505595  2017_Donald J. Trump   american  0.140953
# 510592  2017_Donald J. Trump      obama  0.134954
# 509760  2017_Donald J. Trump       jobs  0.134850
# 511443  2017_Donald J. Trump  protected  0.125096
# 513178  2017_Donald J. Trump      thank  0.109974
# 510951  2017_Donald J. Trump     people  0.106140
# 506179  2017_Donald J. Trump    borders  0.101138

# %%
top_tfidf[top_tfidf['year_Name'].str.contains('Kennedy')]
# Out:
#                    year_Name    term     tfidf
# 381156  1961_John F. Kennedy    0097  0.317063
# 385847  1961_John F. Kennedy     let  0.254751
# 388374  1961_John F. Kennedy   sides  0.249977
# 386993  1961_John F. Kennedy  pledge  0.153077
# 381711  1961_John F. Kennedy     ask  0.102438
# 381945  1961_John F. Kennedy   begin  0.101279
# 383072  1961_John F. Kennedy    dare  0.101279
# 384395  1961_John F. Kennedy   final  0.101279
# 389957  1961_John F. Kennedy   world  0.098060
# 386440  1961_John F. Kennedy     new  0.091869

# %% [markdown]
# ## Visualize TF-IDF

# %% [markdown]
# We can also visualize our TF-IDF results with the data visualization library Altair, which needs to be installed using
#
#     conda install -c conda-forge altair

# %% [markdown]
# Let's make a heatmap that shows the highest TF-IDF scoring words for each president, and let's put a red dot next to two terms of interest: "war" and "peace":
#
# The code below was contributed by [Eric Monson](https://github.com/emonson). Thanks, Eric!

# %%
import altair as alt
import numpy as np

# Terms in this list will get a red dot in the visualization
term_list = ['war', 'peace']

# adding a little randomness to break ties in term ranking
top_tfidf_plusRand = top_tfidf.copy()
top_tfidf_plusRand['tfidf'] = top_tfidf_plusRand['tfidf'] + np.random.rand(top_tfidf.shape[0])*0.0001

# base for all visualizations, with rank calculation
base = alt.Chart(top_tfidf_plusRand).encode(
    x = 'rank:O',
    y = 'year_Name:N'
).transform_window(
    rank = "rank()",
    sort = [alt.SortField("tfidf", order="descending")],
    groupby = ["year_Name"],
)

# heatmap specification
heatmap = base.mark_rect().encode(
    color = 'tfidf:Q'
)

# red circle over terms in above list
circle = base.mark_circle(size=100).encode(
    color = alt.condition(
        alt.FieldOneOfPredicate(field='term', oneOf=term_list),
        alt.value('red'),
        alt.value('#FFFFFF00')        
    )
)

# text labels, white for darker heatmap colors
text = base.mark_text(baseline='middle').encode(
    text = 'term:N',
    color = alt.condition(alt.datum.tfidf >= 0.23, alt.value('white'), alt.value('black'))
)

# display the three superimposed visualizations
(heatmap + circle + text).properties(width = 600)
# Out:
# alt.LayerChart(...)
